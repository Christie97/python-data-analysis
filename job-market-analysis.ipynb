# %% [markdown]
# # Job Market Analysis – QA & Data Analyst Roles
#
# This project analyzes job market trends for QA and Data Analyst roles.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')

# %%
df = pd.read_csv('../data/job-market.csv')
df.head()

# %%
df.info()
df.describe()

# %%
df['Role'].value_counts().plot(kind='bar', title='Job Role Distribution')
plt.show()

# %%
skills = df['Skills'].str.split(', ').explode()
skills.value_counts().head(8).plot(kind='bar', title='Top Skills')
plt.show()

# %% [markdown]
# ## Key Insights
# - Python, SQL, Selenium are in high demand
# - Entry-level roles are common
